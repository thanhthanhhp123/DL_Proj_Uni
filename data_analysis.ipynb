# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
from utils import *

# %%
dataset = load_mnist()

# %%
dataset['train_images'][0].shape
# Out:
# (1, 28, 28)

# %%
data = loadmat('data_set2.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'd', 'dia', 'dr', 'y'])

# %%
X = data['X'].T
d = data['d']
dia = data['dia']
dr = data['dr']
y = data['y']

# %%
Xi = []
yi = []

for i in range(len(X)):
    Xi.append(X[i].reshape(80, 57).T)
    yi.append(y[0][i])

# %%
plt.imshow(Xi[700],vmin = -0.04, vmax = 0.12, cmap = 'rainbow')

# %%
import h5py

with h5py.File('dataset.h5', 'w') as f:
    f.create_dataset('X', data=Xi)
    f.create_dataset('y', data=yi)

# %%
with h5py.File('dataset.h5', 'r') as f:
    X_ = f['X'][:]
    y_ = f['y'][:]

# %%
plt.imshow(X_[10],vmin = -0.04, vmax = 0.12, cmap = 'rainbow')
plt.title(y_[10])
# Out:
# Text(0.5, 1.0, '1')
